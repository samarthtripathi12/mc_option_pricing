# %% [markdown]
# Pre notes

# %%
# %run phase1_gbm.py
# Out:
# Phase 1 complete: Plot and data saved as 'GBM_stock_paths.png' and 'GBM_stock_data.npy'.

# %%
# %run phase2_option.py
# Out:
# European Call Option Price (Monte Carlo): 9.044641144666198

# %% [raw]
# %run phase3_black_scholes.py

# %%
# !dir
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 2499-4169
#
#  Directory of C:\Users\window11\Desktop\MonteCarlo_Finance_Project_5
#
# 01/16/2026  01:59 PM    <DIR>          .
# 01/16/2026  12:23 PM    <DIR>          ..
# 01/16/2026  12:58 PM    <DIR>          .ipynb_checkpoints
# 01/16/2026  12:25 PM    <DIR>          animations
# 01/16/2026  12:23 PM    <DIR>          data
# 01/16/2026  01:47 PM           100,928 GBM_stock_data.npy
# 01/16/2026  01:47 PM           315,588 GBM_stock_paths.png
# 01/16/2026  01:59 PM           418,949 MonteCarlo_Finance_Elevated.ipynb
# 01/16/2026  12:25 PM    <DIR>          New folder
# 01/16/2026  12:23 PM    <DIR>          notebooks
# 01/16/2026  01:47 PM             1,003 phase1_gbm.py
# 01/16/2026  01:50 PM               539 phase2_option.py
# 01/16/2026  01:59 PM               939 phase3_black_scholes.py
# 01/16/2026  12:25 PM    <DIR>          plots
# 01/16/2026  12:23 PM    <DIR>          scripts
# ...

# %%
import os
print (os.getcwd())
# !dir
# Out:
# C:\Users\window11\Desktop\MonteCarlo_Finance_Project_5
#  Volume in drive C is OS
#  Volume Serial Number is 2499-4169
#
#  Directory of C:\Users\window11\Desktop\MonteCarlo_Finance_Project_5
#
# 01/16/2026  02:03 PM    <DIR>          .
# 01/16/2026  12:23 PM    <DIR>          ..
# 01/16/2026  12:58 PM    <DIR>          .ipynb_checkpoints
# 01/16/2026  12:25 PM    <DIR>          animations
# 01/16/2026  12:23 PM    <DIR>          data
# 01/16/2026  01:47 PM           100,928 GBM_stock_data.npy
# 01/16/2026  01:47 PM           315,588 GBM_stock_paths.png
# 01/16/2026  02:03 PM           420,709 MonteCarlo_Finance_Elevated.ipynb
# 01/16/2026  12:25 PM    <DIR>          New folder
# 01/16/2026  12:23 PM    <DIR>          notebooks
# 01/16/2026  01:47 PM             1,003 phase1_gbm.py
# 01/16/2026  01:50 PM               539 phase2_option.py
# 01/16/2026  01:59 PM               939 phase3_black_scholes.py
# 01/16/2026  12:25 PM    <DIR>          plots
# ...

# %%
# %run phase3_black_scholes.py
# Out:
# Monte Carlo Call Price: 0.29209817743866157
# Black-Scholes Call Price: 79.04902746256465

# %%
# %run phase3_black_scholes.py
# Out:
# C:\Users\window11\Desktop\MonteCarlo_Finance_Project_5\phase3_black_scholes.py:28: RuntimeWarning: divide by zero encountered in scalar divide
#   d1 = (np.log(S0 / K) + (r + 0.5 * sigma**2) * T) / (sigma * np.sqrt(T))
# Monte Carlo Call Price: 0.29209817743866157
# Black-Scholes Call Price: 4.877057549928594

# %%
# %run phase3_black_scholes.py
# Out:
# Monte Carlo Call Price: 0.29209817743866157
# Black-Scholes Call Price: 10.450583572185565

# %%
# %run phase3_black_scholes.py
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\Desktop\MonteCarlo_Finance_Project_5\phase3_black_scholes.py:8
#       3 from scipy.stats import norm
#       5 # -------------------------------
#       6 # Load GBM data (Phase 1)
#       7 # -------------------------------
# ----> 8 S = np.load("GBM_stock_data.npy")
#      10 # -------------------------------
#      11 # Parameters (LOCKED)
#      12 # -------------------------------
#      13 S0 = 100.0
#
# File ~\AppData\Roaming\Python\Python314\site-packages\numpy\lib\_npyio_impl.py:489, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     486 else:
#     487     # Try a pickle
#     488     if not allow_pickle:
# --> 489         raise ValueError(
#     490             "This file contains pickled (object) data. If you trust "
# ...

# %%
# %run fix__gbm.py
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\IPython\core\magics\execution.py:728, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     727     fpath = arg_lst[0]
# --> 728     filename = file_finder(fpath)
#     729 except IndexError as e:
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\IPython\utils\path.py:90, in get_py_filename(name)
#      89         return py_name
# ---> 90 raise IOError("File `%r` not found." % name)
#
# OSError: File `'fix__gbm.py'` not found.
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 get_ipython().run_line_magic('run', 'fix__gbm.py')
#
# ...

# %%
# %run fix_gbm.py
# Out:
# GBM fixed

# %%
# %run phase3_black_scholes.py
# Out:
# Monte Carlo Call Price: 10.321026375192464
# Black-Scholes Call Price: 10.450583572185565

# %%
# %run phase3_mc_convergence.py

# %%
# %run phase4_sensitivity_heatmap.py

# %%
# %run phase4_sensitivity_3D.py
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~\Desktop\MonteCarlo_Finance_Project_5\phase4_sensitivity_3D.py:6
#       3 from mpl_toolkits.mplot3d import Axes3D
#       5 # Use the same prices, K_values, sigma_values from Phase 4.1
# ----> 6 K_grid, sigma_grid = np.meshgrid(K_values, sigma_values)
#       8 fig = plt.figure(figsize=(10,7))
#       9 ax = fig.add_subplot(111, projection='3d')
#
# NameError: name 'K_values' is not defined

# %%
# %run phase4_sensitivity_3D.py

# %%
# %run phase5_real_world_validation.py
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# %run phase5_real_world_animation.py
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# %run phase5_real_world_animation_fixed.py
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# %run phase5_real_world_animation_fixed.py
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# %run phase5_real_world_animation.py
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# %run phase5_real_world_animation.py
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# %run interactive_MC_finance.py
# Out:
# [*********************100%***********************]  1 of 1 completed
